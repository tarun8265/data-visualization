# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(x = 'tip', y = 'total_bill', data = df, c = 'g', s = 50)
plt.scatter(x='tip', y='size' , data = df, c = 'r', marker = '+' )
plt.legend( [ 'total_bill' , 'size' ] ,title = 'plot')
plt.xlabel('tip' , fontsize = 14)
plt.ylabel('bill and size')           
sns.lmplot(x = 'tip' , y = 'total_bill' , data = df , fit_reg=False)

# %%
plt.figure()
df.tip.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.figure()
sns.distplot(df.tip, kde = False)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1248\3017333388.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.tip, kde = False)
# <Axes: xlabel='tip'>

# %%
plt.figure()
df.sex.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='sex'>

# %%
plt.figure()
sns.countplot(tips.sex)
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure()
df.groupby( [ 'time' , 'day' ] ) [ 'tip' ] .agg( [ 'mean', 'std'] ).plot(kind = 'barh', stacked = True)
plt.xticks(rotation =10)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1248\2725485933.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby( [ 'time' , 'day' ] ) [ 'tip' ] .agg( [ 'mean', 'std'] ).plot(kind = 'barh', stacked = True)
# (array([0., 1., 2., 3., 4., 5.]),
#  [Text(0.0, 0, '0'),
#   Text(1.0, 0, '1'),
#   Text(2.0, 0, '2'),
#   Text(3.0, 0, '3'),
#   Text(4.0, 0, '4'),
#   Text(5.0, 0, '5')])

# %%
plt.figure()
sns.boxplot(df.tip)
# Out:
# <Axes: ylabel='tip'>

# %%
plt.subplot(121)
sns.distplot(df.tip)

plt.subplot(122)
sns.distplot(df.total_bill)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1248\791397789.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.tip)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1248\791397789.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.total_bill)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
sns.distplot(df.tip, ax=ax2)
sns.distplot(df.total_bill, ax=ax1)
ax1.set_ylabel('total bill')
ax2.set_ylabel('fdg')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1248\1097001102.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.tip, ax=ax2)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1248\1097001102.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.total_bill, ax=ax1)
# Text(0, 0.5, 'fdg')

# %%
# plt.rcParams['figure.dpi']=150
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import scipy.stats
# %matplotlib inline

x=df.tip
y=df.total_bill
slope, intercept, r, p, stderr = scipy.stats.linregress(x, y)

line = f'regression line,  p = {p:.3f}, r={r:.3f}'

fig, ax = plt.subplots(figsize = (10,6),dpi=150)
ax.plot(x, y,  linewidth=0,marker='o', label='Data points')
ax.plot(x, intercept + slope * x, label=line)
ax.set_xlabel('tip amount')
ax.set_ylabel('total_bill')
ax.legend(facecolor='white')
ax.text(8,15,'xyzzzzz',fontsize = 12)
# Out:
# Text(8, 15, 'xyzzzzz')
